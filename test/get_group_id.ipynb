# %%
import requests

# %%
token = '6321353032:AAE6iTBh1R1pFXWolHiKHMdFXI1ks6dmWxs'

# %%
url = f'https://api.telegram.org/bot{token}/getUpdates'

# %%
url
# Out:
# 'https://api.telegram.org/bot6321353032:AAE6iTBh1R1pFXWolHiKHMdFXI1ks6dmWxs/getUpdates'

# %%
r = requests.request("GET",url=url)

# %%
r.json()
# Out:
# {'ok': True,
#  'result': [{'update_id': 897291131,
#    'message': {'message_id': 8158,
#     'from': {'id': 437500463,
#      'is_bot': False,
#      'first_name': 'Duong',
#      'last_name': 'Ngo',
#      'username': 'duongnt96',
#      'language_code': 'en',
#      'is_premium': True},
#     'chat': {'id': -1002015873168,
#      'title': 'THỂ THAO LÀNH MẠNH - ĐẨY LÙI MAI THUÝ',
#      'is_forum': True,
#      'type': 'supergroup'},
#     'date': 1703221014,
#     'message_thread_id': 7017,
#     'reply_to_message': {'message_id': 7017,
#      'from': {'id': 977988551,
#       'is_bot': False,
#       'first_name': 'Khang',
#       'last_name': 'Trinh',
#       'username': 'khangtt2',
#       'language_code': 'en',
#       'is_premium': True},
#      'chat': {'id': -1002015873168,
#       'title': 'THỂ THAO LÀNH MẠNH - ĐẨY LÙI MAI THUÝ',
#       'is_forum': True,
#       'type': 'supergroup'},
#      'date': 1702973247,
#      'message_thread_id': 7017,
# ...
